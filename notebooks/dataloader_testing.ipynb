# %%
import h5py,os
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.chdir('/home/funkl/defects_DLMBL/')

# %% [markdown]
# # prototype

# %%
f = h5py.File('data/isbi/isbi_test_volume.h5','r')

# %%
f.__dict__
# Out:
# {'_libver': (None, 'latest'), '_id': <h5py.h5f.FileID at 0x7f96be5c94f0>}

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['affinities', 'raw']>

# %%
r = f['raw'][:]

# %%
d = f['affinities'][:]

# %%
r.shape
# Out:
# (30, 512, 512)

# %%
d.shape
# Out:
# (17, 30, 512, 512)

# %%
fig,axes = plt.subplots(3,3,figsize=(15,15))
for n,ax in enumerate(axes.flatten()):
    ax.imshow(r[n])

# %%
fig,axes = plt.subplots(3,3,figsize=(15,15))
for n,ax in enumerate(axes.flatten()):
    ax.imshow(d[0,n])

# %%
f.close()

# %%
type(d)
# Out:
# numpy.ndarray

# %% [markdown]
# # test

# %%
from defects_dlmbl.isbi_dataloader import ISBIDataset

# %%
data =ISBIDataset('data/isbi/isbi_test_volume.h5')

# %%
len(data)
# Out:
# 30

# %%
x,y = data[0]

# %%
x.shape,y.shape
# Out:
# (torch.Size([512, 512]), torch.Size([17, 512, 512]))
